# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# Why are these plots misleading or bad?
# See if you can fix them

# %%
flights = sns.load_dataset("flights")

sns.lineplot(data=flights, x="year", y="passengers")
plt.ylim(300, 600)  
plt.title("Air Travel Growth Over Time")
plt.show()

# %%
# Fixed

# %%
tips = sns.load_dataset("tips")

sns.barplot(data=tips, x="day", y="tip")
plt.ylim(2.5, 4)
plt.title("Average Tip by Day")
plt.show()

# %%
# Fixed

# %%
sns.histplot(data=tips, x="total_bill", bins=3)
plt.title("Distribution of Total Bills")
plt.show()

# %%
# Fixed

# %%
penguins = sns.load_dataset("penguins")

sns.lineplot(
    data=penguins,
    x="species",
    y="flipper_length_mm",
    estimator="mean"
)
plt.title("Average Flipper Length by Species")
plt.show()

# %%
# Fixed

# %%
sns.heatmap(penguins[['bill_length_mm', 'bill_depth_mm',
       'flipper_length_mm', 'body_mass_g']].corr(), cmap="rainbow", annot=True)

plt.show()

# %%
# Fixed
