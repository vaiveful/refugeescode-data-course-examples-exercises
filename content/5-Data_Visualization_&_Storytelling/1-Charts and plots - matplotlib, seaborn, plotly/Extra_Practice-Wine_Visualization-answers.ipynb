# %%
# import libraries

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# https://www.kaggle.com/datasets/fedesoriano/spanish-wine-quality-dataset/code
# import the dataset using pandas

df = pd.read_csv('wines_SPA.csv')

df = df[df['region'].isin(['Rioja', 'Ribera del Duero', 'Priorato', 'Toro', 'Vino de Espana'])]

# %% [raw]
# ## Exercises
#
# ### For the questions related to region, winery or types, choose a few that seem interesting to you for the analysis.
# ### It is better to choose options with more entries for the analysis
#
# 1. Create a histogram to visualize the distribution of wine ratings. Is it a normal distribution?
# 2. Create a bar plot showing the average rating of wines from each region.
# 3. Plot a line graph showing the trend of wine prices over the years.
# 4. Create a scatter plot to explore the relationship between wine price and rating.
# 5. Use a box plot to visualize the distribution of wine prices.
# 6. Create a count plot to show the count of wines from each region.
# 7. Create a violin plot to compare the ratings of wines from different regions.
# 8. Visualize the correlation matrix of numerical columns in the dataframe using a heatmap.
# 9. Create a pairplot to visualize relationships across a few muneric variables (you choose)

# %%
df.sample()
# Out:
#           winery                    wine  year  rating  num_reviews country  \
# 978  Vina Sastre  Pesus Ribera del Duero  2003     4.4           59  Espana
#
#                region   price                  type  body  acidity
# 978  Ribera del Duero  509.25  Ribera Del Duero Red   5.0      3.0

# %%
# 1. Create a histogram to visualize the distribution of wine ratings. Is it a normal distribution?

plt.hist(df.rating);

# %%
# 2. Create a bar plot showing the average rating of wines from each region.


sns.barplot(x=df.region, y=df.rating)

# plt.ylim(4, max(df.rating.values) + 0.1)  
#plt.ylim(4, 4.5)
#plt.xticks(rotation=30)
plt.show()

# %%
# 2. Create a bar plot showing the average rating of wines from each region.


sns.barplot(x=df.region, y=df.rating)

# plt.ylim(4, max(df.rating.values) + 0.1)  
plt.ylim(4, 4.5)
plt.xticks(rotation=30)
plt.show()

# %%
# 3. Plot a line graph showing the trend of wine prices over the years.

sns.lineplot(data=df, x='year', y='price')
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
# 4. Create a scatter plot to explore the relationship between wine price and rating.

plt.scatter(df.price, df.rating);

# %%
df.sample()
# Out:
#                 winery       wine  year  rating  num_reviews country  \
# 3883  Bodegas La Horra  Corimbo I  2015     4.2          412  Espana
#
#                 region  price                  type  body  acidity
# 3883  Ribera del Duero   37.9  Ribera Del Duero Red   NaN      NaN

# %%
# 5. Use a box plot to visualize the distribution of wine prices. 

filtered = df[df.price<500]

sns.boxplot(data = df, y='num_reviews')
# Out:
# <Axes: ylabel='num_reviews'>

# %%
# 6. Create a count plot to show the count of wines from each region. Choose 5 regions and filter to show only those regions

sns.countplot(data=df, x='region')
# Out:
# <Axes: xlabel='region', ylabel='count'>

# %%
df.region.value_counts()
# Out:
# region
# Rioja                              2440
# Ribera del Duero                   1413
# Priorato                            686
# Toro                                300
# Vino de Espana                      263
#                                    ...
# Ribera del Gallego-Cinco Villas       1
# Monterrei                             1
# Jerez Cream                           1
# Condado de Huelva                     1
# Abona                                 1
# Name: count, Length: 76, dtype: int64

# %%
# 7. Create a violin plot to compare the ratings of wines from different regions. Use the filtered regions from before

# %%
# 8. Visualize the correlation matrix of numerical columns in the dataframe using a heatmap.

# %%
# 9. Create a pairplot to visualize relationships across a few muneric variables (you choose)
